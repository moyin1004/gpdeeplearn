# %%
from utils import build_dataset, build_iterator, get_time_dif
from importlib import import_module

# %%
dataset = "."  # 数据集

# %%
word = False # True for word, False for char

x = import_module('models.' + "TextRNN")
embedding = 'embedding_SougouNews.npz'
config = x.Config(dataset, embedding)

# %%
vocab, train_data, dev_data, test_data = build_dataset(config, word)
# Out:
# Vocab size: 4762
# 180000it [00:01, 179493.23it/s]
# 10000it [00:00, 219053.45it/s]
# 10000it [00:00, 220498.69it/s]

# %%
train_data[0]
# Out:
# ([14,
#   125,
#   55,
#   45,
#   35,
#   307,
#   4,
#   81,
#   161,
#   941,
#   258,
#   494,
#   2,
#   175,
#   48,
#   145,
#   97,
#   17,
#   4760,
#   4760,
#   4760,
#   4760,
#   4760,
#   4760,
#   4760,
#   4760,
#   4760,
#   4760,
#   4760,
#   4760,
#   4760,
#   4760],
#  3,
#  18)

# %%
UNK, PAD = '<UNK>', '<PAD>'  # 未知字，padding符号
vocab.get(UNK)
# Out:
# 4760

# %%
vocab.get(PAD)
# Out:
# 4761
